# %%
import pandas as pd

# %%
data_SHHS1 = pd.read_csv('data_SHHS1.csv')

# %%
data_SHHS1.shape
# Out:
# (1122206, 268)

# %%
data_SHHS1.head()
# Out:
#         patient  CA_relative_3  CT_relative_3  POD_relative_3  \
# 0  shhs1-201955       0.460600            0.0        0.223333
# 1  shhs1-201955       0.410256            0.0        0.000000
# 2  shhs1-201955       0.324889            0.0        0.000000
# 3  shhs1-201955       0.280256            0.0        0.000000
# 4  shhs1-201955       0.268667            0.0        0.000000
#
#    AODmax_relative_3  AOD100_relative_3  ODI_relative_3  DL_u_relative_3  \
# 0           0.406667           1.086667            12.0             67.0
# 1           0.000000           0.000000             0.0              0.0
# 2           0.000000           0.000000             0.0              0.0
# 3           0.000000           0.000000             0.0              0.0
# 4           0.000000           0.000000             0.0              0.0
#
#    DL_sd_relative_3  DA100_u_relative_3  ...         event_name  event_start  \
# ...

# %%
list(data_SHHS1.columns)
# Out:
# ['patient',
#  'CA_relative_3',
#  'CT_relative_3',
#  'POD_relative_3',
#  'AODmax_relative_3',
#  'AOD100_relative_3',
#  'ODI_relative_3',
#  'DL_u_relative_3',
#  'DL_sd_relative_3',
#  'DA100_u_relative_3',
#  'DA100_sd_relative_3',
#  'DAmax_u_relative_3',
#  'DAmax_sd_relative_3',
#  'DD100_u_relative_3',
#  'DD100_sd_relative_3',
#  'DDmax_u_relative_3',
#  'DDmax_sd_relative_3',
#  'DS_u_relative_3',
#  'DS_sd_relative_3',
#  'TD_u_relative_3',
#  'TD_sd_relative_3',
#  'DL_a_u_relative_3',
#  'DL_a_sd_relative_3',
#  'DL_b_u_relative_3',
#  'DL_b_sd_relative_3',
#  'CA_relative_5',
#  'CT_relative_5',
#  'POD_relative_5',
#  'AODmax_relative_5',
#  'AOD100_relative_5',
#  'ODI_relative_5',
#  'DL_u_relative_5',
#  'DL_sd_relative_5',
#  'DA100_u_relative_5',
#  'DA100_sd_relative_5',
#  'DAmax_u_relative_5',
#  'DAmax_sd_relative_5',
#  'DD100_u_relative_5',
#  'DD100_sd_relative_5',
#  'DDmax_u_relative_5',
#  'DDmax_sd_relative_5',
#  'DS_u_relative_5',
# ...

# %%
data_SHHS1.loc[data_SHHS1['outcome'] == 1].shape
# Out:
# (1082225, 268)

# %%
data_SHHS1.loc[data_SHHS1['outcome'] == 0].shape
# Out:
# (39981, 268)

# %%
data_SHHS1_sample = data_SHHS1.sample(n=50000)

# %%
data_SHHS1_sample.to_csv('data_SHHS1_sample.csv', index=False)
